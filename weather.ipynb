# %%
# Import libraries
import pandas
import matplotlib.pyplot as plt
import datetime
import numpy
import matplotlib.dates as mdates
# read the data from the CSV files into Pandas DataFrames
# prodSalesDF = pandas.io.parsers.read_csv( 'product_sales_sample.csv' )
dayPartsDF = pandas.io.parsers.read_csv( 'dayparts_sample.csv' )
weatherDF = pandas.io.parsers.read_csv( 'weather_sample.csv' )
dmgrphcsDF = pandas.io.parsers.read_csv( 'demographics_sample.csv' )

# %%
# # Drop the first column, it just has the description of data
# descDmgDF = dmgrphcsDF[0:1]
# dmgrphcsDF.drop( dmgrphcsDF.index[[0]], inplace=True )
# # reset the index 
# dmgrphcsDF.reset_index( drop=True, inplace=True )
# print dmgrphcsDF.columns
print weatherDF.columns
# Out:
# Index([u'xFilter', u'xError', u'FINAL_EXEC_FLAG', u'LEVEL', u'GEO_CODE', u'GEO_NAME', u'Unnamed: 6', u'TY_DATE', u'LY_DATE', u'TY_MODEL', u'TY_NON_WX_MODEL', u'TY_SIG_TEMP_NEG_PCT', u'TY_SIG_TEMP_POS_PCT', u'TY_SIG_RAIN_PCT', u'TY_SIG_SNOW_PCT', u'TY_SIG_SNOW_AND_RAIN_PCT', u'TY_NULL_FORECAST', u'TY_MISSING_TEMP', u'TY_MISSING_PRECIP', u'LY_MODEL', u'LY_NON_WX_MODEL', u'LY_SIG_TEMP_NEG_PCT', u'LY_SIG_TEMP_POS_PCT', u'LY_SIG_RAIN_PCT', u'LY_SIG_SNOW_PCT', u'LY_SIG_SNOW_AND_RAIN_PCT', u'LY_NULL_FORECAST', u'LY_MISSING_TEMP', u'LY_MISSING_PRECIP', u'TY_AVG_MIN_TEMP', u'TY_AVG_MAX_TEMP', u'TY_TOTAL_PRECIP', u'TY_TOTAL_SNOW', u'LY_AVG_MIN_TEMP', u'LY_AVG_MAX_TEMP', u'LY_TOTAL_PRECIP', u'LY_TOTAL_SNOW', u'NRM_AVG_MIN_TEMP', u'NRM_AVG_MAX_TEMP', u'NRM_TOTAL_PRECIP', u'NRM_TOTAL_SNOW', u'tytrn', u'lytrn', u'comp', u'tybase', u'lybase', u'reasoncode', u'monthyr', u'tychg', u'lychg', u'impactty', u'impactly', u'tycompwoweather', u'compduetoweather', u'Datafile', u'_CreateDt', u'_CreateBy'], dt
# ...

# %%
# convert the ty_date and ly_date cols to datetime objects
# and also get weekday type data as well
weatherDF['datetime_ty'] = pandas.to_datetime( weatherDF['TY_DATE'] )
weatherDF['datetime_ly'] = pandas.to_datetime( weatherDF['LY_DATE'] )

# %%
# Plot weather data
yearsLocPlot = mdates.YearLocator()   # every year
monthsLocPlot = mdates.MonthLocator()  # every month
daysLocPlot = mdates.DayLocator()
dateLocPlot = mdates.DateLocator()
dateTickFmt = mdates.DateFormatter('%d')
# Plot 2011 data
fig, (ax0, ax1, ax2, ax3) = plt.subplots(nrows=4, sharex=True, figsize=(11,8))
ax0.plot(weatherDF['datetime_ty'].tolist(), \
         weatherDF['TY_AVG_MIN_TEMP'].tolist(),\
         'bo-')
ax0.set_ylabel('Avg. Min Temp.', fontsize=12)
ax0.set_title('Weather Jan-2011', fontsize=16)

ax1.plot(weatherDF['datetime_ty'].tolist(), \
         weatherDF['TY_AVG_MAX_TEMP'].tolist(),\
         'bo-')
ax1.set_ylabel('Avg. Max Temp.', fontsize=12)

ax2.plot(weatherDF['datetime_ty'].tolist(), \
         weatherDF['TY_TOTAL_PRECIP'].tolist(),\
         'bo-')
ax2.set_ylabel('Tot. Prec.', fontsize=12)

ax3.plot(weatherDF['datetime_ty'].tolist(), \
         weatherDF['TY_TOTAL_SNOW'].tolist(),\
         'bo-')
ax3.set_ylabel('Tot. Snow.', fontsize=12)


# format the ticks
ax0.xaxis.set_major_locator(daysLocPlot)
ax0.xaxis.set_major_formatter(dateTickFmt)
ax0.xaxis.set_minor_locator(daysLocPlot)

ax1.xaxis.set_major_locator(daysLocPlot)
ax1.xaxis.set_major_formatter(dateTickFmt)
ax1.xaxis.set_minor_locator(daysLocPlot)

ax2.xaxis.set_major_locator(daysLocPlot)
ax2.xaxis.set_major_formatter(dateTickFmt)
ax2.xaxis.set_minor_locator(daysLocPlot)

ax3.xaxis.set_major_locator(daysLocPlot)
ax3.xaxis.set_major_formatter(dateTickFmt)
ax3.xaxis.set_minor_locator(daysLocPlot)

datemin = weatherDF['datetime_ty'].min().to_datetime()
datemax = weatherDF['datetime_ty'].max().to_datetime()
ax3.set_xlim(datemin, datemax)

fig.savefig('figs/weather-2011.png', bbox_inches='tight', \
                        pad_inches=0)

# %%
# Plot weather data
yearsLocPlot = mdates.YearLocator()   # every year
monthsLocPlot = mdates.MonthLocator()  # every month
daysLocPlot = mdates.DayLocator()
dateLocPlot = mdates.DateLocator()
dateTickFmt = mdates.DateFormatter('%d')
# Plot 2010 data
fig, (ax0, ax1, ax2, ax3) = plt.subplots(nrows=4, sharex=True, figsize=(11,8))
ax0.plot(weatherDF['datetime_ly'].tolist(), \
         weatherDF['LY_AVG_MIN_TEMP'].tolist(),\
         'bo-')
ax0.set_ylabel('Avg. Min Temp.', fontsize=12)
ax0.set_title('Weather Jan-2010', fontsize=16)

ax1.plot(weatherDF['datetime_ly'].tolist(), \
         weatherDF['LY_AVG_MAX_TEMP'].tolist(),\
         'bo-')
ax1.set_ylabel('Avg. Max Temp.', fontsize=12)

ax2.plot(weatherDF['datetime_ly'].tolist(), \
         weatherDF['LY_TOTAL_PRECIP'].tolist(),\
         'bo-')
ax2.set_ylabel('Tot. Prec.', fontsize=12)

ax3.plot(weatherDF['datetime_ly'].tolist(), \
         weatherDF['LY_TOTAL_SNOW'].tolist(),\
         'bo-')
ax3.set_ylabel('Tot. Snow.', fontsize=12)


# format the ticks
ax0.xaxis.set_major_locator(daysLocPlot)
ax0.xaxis.set_major_formatter(dateTickFmt)
ax0.xaxis.set_minor_locator(daysLocPlot)

ax1.xaxis.set_major_locator(daysLocPlot)
ax1.xaxis.set_major_formatter(dateTickFmt)
ax1.xaxis.set_minor_locator(daysLocPlot)

ax2.xaxis.set_major_locator(daysLocPlot)
ax2.xaxis.set_major_formatter(dateTickFmt)
ax2.xaxis.set_minor_locator(daysLocPlot)

ax3.xaxis.set_major_locator(daysLocPlot)
ax3.xaxis.set_major_formatter(dateTickFmt)
ax3.xaxis.set_minor_locator(daysLocPlot)

datemin = weatherDF['datetime_ly'].min().to_datetime()
datemax = weatherDF['datetime_ly'].max().to_datetime()
ax3.set_xlim(datemin, datemax)

fig.savefig('figs/weather-2010.png', bbox_inches='tight', \
                        pad_inches=0)

# %%
# Set some initial formatting for making plots
yearsLocPlot = mdates.YearLocator()   # every year
monthsLocPlot = mdates.MonthLocator()  # every month
daysLocPlot = mdates.DayLocator()
dateLocPlot = mdates.DateLocator()
dateTickFmt = mdates.DateFormatter('%d')

# %%
dayPartsDF1364 = dayPartsDF[ dayPartsDF['REST_KEY'] == 1364 ]
dayPartsDF1364['date'] = pandas.to_datetime( dayPartsDF1364['Reporting Day'] )
# groupby by date to check for variations
dayGroup1364 = dayPartsDF1364.groupby('date')
# get a sum of sales and transactions by days
daySales1364 = dayGroup1364.sum()
# Divide data into two parts one in 2010 and the other
# in 2011 and then plot them (for rest 1364). This makes it easy to
# visualize things.
date2011 = numpy.datetime64( datetime.date(2011,1,1) )
daySales13642010 = daySales1364[ daySales1364.index < date2011 ]
daySales13642011 = daySales1364[ daySales1364.index >= date2011 ]

# Plot 2010 data for rest 1364
fig, (ax0, ax1) = plt.subplots(nrows=2, sharex=True, figsize=(11,8))
ax0.plot(daySales13642010.index.tolist(), \
         daySales13642010['Daypart Sales $'].tolist(),\
         'bo-')
ax0.set_ylabel('Sales ($)', fontsize=14)
ax0.set_title('Data for Jan-2010', fontsize=16)

ax1.plot(daySales13642010.index.tolist(), \
         daySales13642010['Daypart Transaction Qty'].tolist(),\
         'bo-')
ax1.set_ylabel('Transaction Qty', fontsize=14)

# format the ticks
ax0.xaxis.set_major_locator(daysLocPlot)
ax0.xaxis.set_major_formatter(dateTickFmt)
ax0.xaxis.set_minor_locator(daysLocPlot)

ax1.xaxis.set_major_locator(daysLocPlot)
ax1.xaxis.set_major_formatter(dateTickFmt)
ax1.xaxis.set_minor_locator(daysLocPlot)

datemin = daySales13642010.index.min().to_datetime()
datemax = daySales13642010.index.max().to_datetime()
ax1.set_xlim(datemin, datemax)

fig.savefig('figs/Jan2011-1364-sales.png', bbox_inches='tight', \
                        pad_inches=0)

# %%
######################## 1364 ####################################
######################## 1364 ####################################
dayPartsDF1364 = dayPartsDF[ dayPartsDF['REST_KEY'] == 1364 ]
dayPartsDF1364['date'] = pandas.to_datetime( dayPartsDF1364['Reporting Day'] )
# groupby by date to check for variations
dayGroup1364 = dayPartsDF1364.groupby('date')
# get a sum of sales and transactions by days
daySales1364 = dayGroup1364.sum()
# Divide data into two parts one in 2011 and the other
# in 2011 and then plot them (for rest 1364). This makes it easy to
# visualize things.
date2011 = numpy.datetime64( datetime.date(2011,1,1) )
daySales13642010 = daySales1364[ daySales1364.index < date2011 ]
daySales13642011 = daySales1364[ daySales1364.index >= date2011 ]
######################## 1364 ####################################
######################## 1364 ####################################

######################## 13604 ####################################
######################## 13604 ####################################
dayPartsDF13604 = dayPartsDF[ dayPartsDF['REST_KEY'] == 13604 ]
dayPartsDF13604['date'] = pandas.to_datetime( dayPartsDF13604['Reporting Day'] )
# groupby by date to check for variations
dayGroup13604 = dayPartsDF13604.groupby('date')
# get a sum of sales and transactions by days
daySales13604 = dayGroup13604.sum()
# Divide data into two parts one in 2011 and the other
# in 2011 and then plot them (for rest 13604). This makes it easy to
# visualize things.
date2011 = numpy.datetime64( datetime.date(2011,1,1) )
daySales136042010 = daySales13604[ daySales13604.index < date2011 ]
daySales136042011 = daySales13604[ daySales13604.index >= date2011 ]
######################## 13604 ####################################
######################## 13604 ####################################

######################## 13369 ####################################
######################## 13369 ####################################
dayPartsDF13369 = dayPartsDF[ dayPartsDF['REST_KEY'] == 13369 ]
dayPartsDF13369['date'] = pandas.to_datetime( dayPartsDF13369['Reporting Day'] )
# groupby by date to check for variations
dayGroup13369 = dayPartsDF13369.groupby('date')
# get a sum of sales and transactions by days
daySales13369 = dayGroup13369.sum()
# Divide data into two parts one in 2011 and the other
# in 2011 and then plot them (for rest 13369). This makes it easy to
# visualize things.
date2011 = numpy.datetime64( datetime.date(2011,1,1) )
daySales133692010 = daySales13369[ daySales13369.index < date2011 ]
daySales133692011 = daySales13369[ daySales13369.index >= date2011 ]
######################## 13369 ####################################
######################## 13369 ####################################

######################## 5357 ####################################
######################## 5357 ####################################
dayPartsDF5357 = dayPartsDF[ dayPartsDF['REST_KEY'] == 5357 ]
dayPartsDF5357['date'] = pandas.to_datetime( dayPartsDF5357['Reporting Day'] )
# groupby by date to check for variations
dayGroup5357 = dayPartsDF5357.groupby('date')
# get a sum of sales and transactions by days
daySales5357 = dayGroup5357.sum()
# Divide data into two parts one in 2011 and the other
# in 2011 and then plot them (for rest 5357). This makes it easy to
# visualize things.
date2011 = numpy.datetime64( datetime.date(2011,1,1) )
daySales53572010 = daySales5357[ daySales5357.index < date2011 ]
daySales53572011 = daySales5357[ daySales5357.index >= date2011 ]
######################## 5357 ####################################
######################## 5357 ####################################

# %%
# Plot 2011 data for rest 1364
fig, (ax0, ax1) = plt.subplots(nrows=2, sharex=True, figsize=(11,8))

ax0.plot(daySales13642011.index.tolist(), \
         daySales13642011['Daypart Sales $'].tolist(),\
         'bo-', label='REST - 1364')
ax0.plot(daySales136042011.index.tolist(), \
         daySales136042011['Daypart Sales $'].tolist(),\
         'r*-', label='REST - 13604')
ax0.plot(daySales133692011.index.tolist(), \
         daySales133692011['Daypart Sales $'].tolist(),\
         'g+-', label='REST - 13369')
ax0.plot(daySales53572011.index.tolist(), \
         daySales53572011['Daypart Sales $'].tolist(),\
         'k^-', label='REST - 5357')

ax0.set_ylabel('Sales ($)', fontsize=14)
ax0.set_title('Data for Jan-2011', fontsize=16)

ax1.plot(daySales13642011.index.tolist(), \
         daySales13642011['Daypart Transaction Qty'].tolist(),\
         'bo-')
ax1.plot(daySales136042011.index.tolist(), \
         daySales136042011['Daypart Transaction Qty'].tolist(),\
         'r*-')
ax1.plot(daySales133692011.index.tolist(), \
         daySales133692011['Daypart Transaction Qty'].tolist(),\
         'g+-')
ax1.plot(daySales53572011.index.tolist(), \
         daySales53572011['Daypart Transaction Qty'].tolist(),\
         'k^-')

ax0.legend(bbox_to_anchor=(1., 0.25))

# format the ticks
ax0.xaxis.set_major_locator(daysLocPlot)
ax0.xaxis.set_major_formatter(dateTickFmt)
ax0.xaxis.set_minor_locator(daysLocPlot)

ax1.xaxis.set_major_locator(daysLocPlot)
ax1.xaxis.set_major_formatter(dateTickFmt)
ax1.xaxis.set_minor_locator(daysLocPlot)

datemin = daySales13642011.index.min().to_datetime()
datemax = daySales13642011.index.max().to_datetime()
ax1.set_xlim(datemin, datemax)

fig.savefig('figs/Jan2011-byrest-sales.png', bbox_inches='tight', \
                        pad_inches=0)

# %%
# Plot 2010 data for rest 1364
fig, (ax0, ax1) = plt.subplots(nrows=2, sharex=True, figsize=(11,8))

ax0.plot(daySales13642010.index.tolist(), \
         daySales13642010['Daypart Sales $'].tolist(),\
         'bo-', label='REST - 1364')
ax0.plot(daySales136042010.index.tolist(), \
         daySales136042010['Daypart Sales $'].tolist(),\
         'r*-', label='REST - 13604')
ax0.plot(daySales133692010.index.tolist(), \
         daySales133692010['Daypart Sales $'].tolist(),\
         'g+-', label='REST - 13369')
ax0.plot(daySales53572010.index.tolist(), \
         daySales53572010['Daypart Sales $'].tolist(),\
         'k^-', label='REST - 5357')

ax0.set_ylabel('Sales ($)', fontsize=14)
ax0.set_title('Data for Jan-2010', fontsize=16)

ax1.plot(daySales13642010.index.tolist(), \
         daySales13642010['Daypart Transaction Qty'].tolist(),\
         'bo-')
ax1.plot(daySales136042010.index.tolist(), \
         daySales136042010['Daypart Transaction Qty'].tolist(),\
         'r*-')
ax1.plot(daySales133692010.index.tolist(), \
         daySales133692010['Daypart Transaction Qty'].tolist(),\
         'g+-')
ax1.plot(daySales53572010.index.tolist(), \
         daySales53572010['Daypart Transaction Qty'].tolist(),\
         'k^-')

ax0.legend(bbox_to_anchor=(1., 0.25))

# format the ticks
ax0.xaxis.set_major_locator(daysLocPlot)
ax0.xaxis.set_major_formatter(dateTickFmt)
ax0.xaxis.set_minor_locator(daysLocPlot)

ax1.xaxis.set_major_locator(daysLocPlot)
ax1.xaxis.set_major_formatter(dateTickFmt)
ax1.xaxis.set_minor_locator(daysLocPlot)

datemin = daySales13642010.index.min().to_datetime()
datemax = daySales13642010.index.max().to_datetime()
ax1.set_xlim(datemin, datemax)

fig.savefig('figs/Jan2010-byrest-sales.png', bbox_inches='tight', \
                        pad_inches=0)

# %%
totSalesByRest2010 = [ daySales13642010['Daypart Sales $'].sum(),\
                      daySales136042010['Daypart Sales $'].sum(),\
                      daySales133692010['Daypart Sales $'].sum(),
                      daySales53572010['Daypart Sales $'].sum() ]

totSalesByRest2011 = [ daySales13642011['Daypart Sales $'].sum(),\
                      daySales136042011['Daypart Sales $'].sum(),\
                      daySales133692011['Daypart Sales $'].sum(),
                      daySales53572011['Daypart Sales $'].sum() ]


totXtnsByRest2010 = [ daySales13642010['Daypart Transaction Qty'].sum(),\
                      daySales136042010['Daypart Transaction Qty'].sum(),\
                      daySales133692010['Daypart Transaction Qty'].sum(),
                      daySales53572010['Daypart Transaction Qty'].sum() ]

totXtnsByRest2011 = [ daySales13642011['Daypart Transaction Qty'].sum(),\
                      daySales136042011['Daypart Transaction Qty'].sum(),\
                      daySales133692011['Daypart Transaction Qty'].sum(),
                      daySales53572011['Daypart Transaction Qty'].sum() ]

keysRest = [ '1364', '13604', '13369', '5357' ]

# %%
# Plot the data
xAxisWidth = 0.35
xAxis2010 = [ i for i in range(len(keysRest)) ]
xAxis2011 = [ i+xAxisWidth for i in range(len(keysRest)) ]
xAxisTicks = [ i+xAxisWidth/2 for i in range(len(keysRest)) ]
fig, (ax0, ax1) = plt.subplots(nrows=2, sharex=True, figsize=(11,8))
ax0.bar(xAxis2010, \
         totSalesByRest2010,\
         align='center', width=xAxisWidth,\
               color=['steelblue'], label = 'Year-2010')
ax0.bar(xAxis2011, \
         totSalesByRest2011,\
         align='center', width=xAxisWidth,\
               color=['crimson'], label = 'Year-2011')
ax0.set_ylabel('Sales ($)', fontsize=14)
ax0.grid(zorder=0)
ax0.set_title('Sales/Transactions comparison by Year', fontsize=16)
ax0.set_xticklabels( keysRest )
ax0.set_xticks(xAxisTicks)
ax0.legend(bbox_to_anchor=(0.65, 0.1))



ax1.bar(xAxis2010, \
         totXtnsByRest2010,\
         align='center', width=xAxisWidth,\
               color=['steelblue'], label = 'Year-2010')
ax1.bar(xAxis2011, \
         totXtnsByRest2011,\
         align='center', width=xAxisWidth,\
               color=['crimson'], label = 'Year-2011')
# ax0.xticks(range(len(dayNameSales.index.tolist())), dayNameSales.index.tolist(), size='small')
ax1.set_ylabel('Transactions', fontsize=14)
ax1.grid(zorder=0)
ax1.set_xticklabels( keysRest )
ax1.set_xticks(xAxisTicks)
fig.savefig('figs/sales-byyear-byrest.png', bbox_inches='tight', \
                        pad_inches=0)
